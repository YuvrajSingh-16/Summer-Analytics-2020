# %% [markdown]
# # Employee Attrition Prediction

# %% [markdown]
# ## Summer Analytics 2020 Kaggle Hackathon

# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

# %%
# Setting to display all the columns
pd.set_option("max_columns", None)

# Importing datasets
X = pd.read_csv("data/train.csv")
X_test = pd.read_csv("data/test.csv")
X.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  Gender  JobInvolvement                 JobRole  \
# 0                        3  Female               3   Laboratory Technician
# ...

# %%
# Splitting into X and y
y = X["Attrition"]
X.drop(["Attrition", "Id"], axis=1, inplace=True)
X.shape, y.shape
# Out:
# ((1628, 27), (1628,))

# %%
# Splitting dataset into training and test datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X,y,test_size=0.3,random_state=1)

# %% [markdown]
# ## Encoding

# %%
# Checking the unique values in object columns to see whether to do hotencoding or labelencoding on them
obj_dict_train={obj_col: list(X_train[obj_col].unique()) for obj_col in X_train.select_dtypes(include='object')}
obj_dict_train  # Object dictionary for train set
# Out:
# {'BusinessTravel': ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'],
#  'Department': ['Research & Development', 'Sales', 'Human Resources'],
#  'EducationField': ['Life Sciences',
#   'Medical',
#   'Marketing',
#   'Technical Degree',
#   'Other',
#   'Human Resources'],
#  'Gender': ['Male', 'Female'],
#  'JobRole': ['Research Scientist',
#   'Sales Representative',
#   'Laboratory Technician',
#   'Sales Executive',
#   'Healthcare Representative',
#   'Manager',
#   'Manufacturing Director',
#   'Research Director',
#   'Human Resources'],
#  'MaritalStatus': ['Married', 'Single', 'Divorced'],
#  'OverTime': ['No', 'Yes']}

# %%
# Object dictionary for validation set
obj_dict_valid={obj_col: list(X_train[obj_col].unique()) for obj_col in X_train.select_dtypes(include='object')}
obj_dict_valid
# Out:
# {'BusinessTravel': ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'],
#  'Department': ['Research & Development', 'Sales', 'Human Resources'],
#  'EducationField': ['Life Sciences',
#   'Medical',
#   'Marketing',
#   'Technical Degree',
#   'Other',
#   'Human Resources'],
#  'Gender': ['Male', 'Female'],
#  'JobRole': ['Research Scientist',
#   'Sales Representative',
#   'Laboratory Technician',
#   'Sales Executive',
#   'Healthcare Representative',
#   'Manager',
#   'Manufacturing Director',
#   'Research Director',
#   'Human Resources'],
#  'MaritalStatus': ['Married', 'Single', 'Divorced'],
#  'OverTime': ['No', 'Yes']}
